# %% [markdown]
# # Analise Exploratoria
# ## Teste de extração de caracteristicas

# %%
from IPython.display import Image
from os import popen

# %%
img = popen("ls *.jpg").read()

# %%
imgs = img.split("\n")

# %%
Image(imgs[4])
